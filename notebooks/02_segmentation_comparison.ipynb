# %% [markdown]
# # 02 — Segmentation Comparison
#
# **Purpose:** Compare nuclear segmentation methods (Otsu+Watershed vs Cellpose)
# on sample images. Visualize masks, compute IoU/Dice vs ground truth.
#
# ---

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# from focipy.io_utils import load_image
# from focipy.segmentation import OtsuWatershedSegmenter, CellposeSegmenter

# %% [markdown]
# ## Load sample DAPI image

# %%
# TODO: Load DAPI channel from sample image

# %% [markdown]
# ## Otsu + Watershed segmentation

# %%
# TODO: Run Otsu segmentation, show overlay

# %% [markdown]
# ## Cellpose segmentation

# %%
# TODO: Run Cellpose segmentation, show overlay

# %% [markdown]
# ## Quantitative comparison (IoU, Dice, count accuracy)

# %%
# TODO: Compare both methods against ground truth
