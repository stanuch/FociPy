# %% [markdown]
# # 03 — Foci Detection Tuning
#
# **Purpose:** Calibrate foci detection parameters (DoG sigma, threshold)
# on sample images with ground truth annotations.
#
# ---

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# from focipy.io_utils import load_image
# from focipy.foci_detection import detect_foci_dog, detect_foci_log

# %% [markdown]
# ## Load XRCC1 channel + ground truth

# %%
# TODO: Load XRCC1 image and ground truth annotations

# %% [markdown]
# ## Parameter sweep (grid search)

# %%
# TODO: Test DoG with varying sigma_low, sigma_high, threshold
# Compute Precision, Recall, F1 for each combination

# %% [markdown]
# ## Precision / Recall / F1 plots

# %%
# TODO: Plot metrics vs threshold, identify optimal parameters

# %% [markdown]
# ## Visual inspection of detections

# %%
# TODO: Overlay detected foci on image (TP=green, FP=red, FN=blue)
