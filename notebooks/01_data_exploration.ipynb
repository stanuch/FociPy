# %% [markdown]
# # 01 — Data Exploration
#
# **Purpose:** Inspect raw microscopy data before building the pipeline.
# Check channels, histograms, SNR, nucleus sizes, and image quality.
#
# ---

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt

# When focipy is installed (pip install -e .):
# from focipy.io_utils import load_image, find_images

# %%
# --- Configuration ---
DATA_DIR = Path("../data/raw")
EXPERIMENT = "experiment_01"  # change to your folder name

# %% [markdown]
# ## Load and inspect a sample image

# %%
# TODO: Load image and print shape, dtype, min, max, channels

# %% [markdown]
# ## Visualize channels (DAPI, XRCC1)

# %%
# TODO: Display DAPI and XRCC1 channels side by side

# %% [markdown]
# ## Intensity histograms

# %%
# TODO: Plot histograms for each channel

# %% [markdown]
# ## Notes & observations
#
# - *Write your observations about data quality here*
