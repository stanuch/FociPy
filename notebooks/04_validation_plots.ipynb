# %% [markdown]
# # 04 — Validation Plots
#
# **Purpose:** Generate publication-ready figures for the master's thesis.
# Bland-Altman, correlation, dose-response curves.
#
# ---

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# from focipy.visualization import plot_bland_altman, plot_correlation, plot_dose_response

# %% [markdown]
# ## Load results

# %%
# TODO: Load per-nucleus CSV, ground truth manual counts

# %% [markdown]
# ## Bland-Altman plot (automated vs manual)

# %%
# TODO: Bland-Altman analysis

# %% [markdown]
# ## Correlation plot + CCC

# %%
# TODO: Pearson R, R², CCC

# %% [markdown]
# ## Dose-response curve

# %%
# TODO: Mean foci count vs UV dose, with error bars

# %% [markdown]
# ## Export figures (SVG/PDF)

# %%
# TODO: Save publication-ready figures
# fig.savefig('figures/dose_response.svg', dpi=300, bbox_inches='tight')
